# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/harissriramoju/DataScience-Samples/master/gapminder.tsv",sep='\t')

# %%
df.head(5)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# To know the size of my data(df)

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
country_df=df['country']

# %%
country_df.head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
country_df.tail()
# Out:
# 1699    Zimbabwe
# 1700    Zimbabwe
# 1701    Zimbabwe
# 1702    Zimbabwe
# 1703    Zimbabwe
# Name: country, dtype: object

# %%
subset=df[['country','continent','pop','year']]
subset.head()
# Out:
#        country continent       pop  year
# 0  Afghanistan      Asia   8425333  1952
# 1  Afghanistan      Asia   9240934  1957
# 2  Afghanistan      Asia  10267083  1962
# 3  Afghanistan      Asia  11537966  1967
# 4  Afghanistan      Asia  13079460  1972

# %% [markdown]
# there are some specific method for  subsetting data.import method are 'loc' and 'iloc'

# %%
df.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.loc[99]
# Out:
# country      Bangladesh
# continent          Asia
# year               1967
# lifeExp          43.453
# pop            62821884
# gdpPercap    721.186086
# Name: 99, dtype: object

# %%
df.iloc[-1]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
number_of_rows=df.shape[0]
#df.shape which return tuple(1704,6)
last_row_index=number_of_rows-1;
df.loc[last_row_index]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
df.tail(n=1)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.head(n=1)
# Out:
#        country continent  year  lifeExp      pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801  8425333  779.445314

# %%
subset_row=df.loc[0]
subset_row
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
type(subset_row)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Retrieving Multiple rows of data

# %%
df.loc[[0,9,99,999]]
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 0    Afghanistan      Asia  1952   28.801   8425333   779.445314
# 9    Afghanistan      Asia  1997   41.763  22227415   635.341351
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130

# %%
df.iloc[[0,9,99,999]]
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 0    Afghanistan      Asia  1952   28.801   8425333   779.445314
# 9    Afghanistan      Asia  1997   41.763  22227415   635.341351
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130

# %%
df.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.iloc[99]
# Out:
# country      Bangladesh
# continent          Asia
# year               1967
# lifeExp          43.453
# pop            62821884
# gdpPercap    721.186086
# Name: 99, dtype: object

# %%
df.iloc[[0,9,99,999]]
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 0    Afghanistan      Asia  1952   28.801   8425333   779.445314
# 9    Afghanistan      Asia  1997   41.763  22227415   635.341351
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130

# %%
df.loc[[0,9,99,999]]
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 0    Afghanistan      Asia  1952   28.801   8425333   779.445314
# 9    Afghanistan      Asia  1997   41.763  22227415   635.341351
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130

# %%
df.loc[[0,99,100,101]]
# Out:
#          country continent  year  lifeExp       pop   gdpPercap
# 0    Afghanistan      Asia  1952   28.801   8425333  779.445314
# 99    Bangladesh      Asia  1967   43.453  62821884  721.186086
# 100   Bangladesh      Asia  1972   45.252  70759295  630.233627
# 101   Bangladesh      Asia  1977   46.923  80428306  659.877232

# %%
df.iloc[[0,99,100,101,-1]]
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 99     Bangladesh      Asia  1967   43.453  62821884  721.186086
# 100    Bangladesh      Asia  1972   45.252  70759295  630.233627
# 101    Bangladesh      Asia  1977   46.923  80428306  659.877232
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.loc[:]
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.loc[:,]
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.loc[[8,88,888],]
# Out:
#          country continent  year  lifeExp       pop     gdpPercap
# 8    Afghanistan      Asia  1992   41.674  16317921    649.341395
# 88       Bahrain      Asia  1972   63.300    230800  18268.658390
# 888      Liberia    Africa  1952   38.480    863308    575.572996

# %%
df.iloc[[8,88,888],[2,4]]
# Out:
#      year       pop
# 8    1992  16317921
# 88   1972    230800
# 888  1952    863308

# %%
df.iloc[:,[2,4,-1]]
# Out:
#       year       pop   gdpPercap
# 0     1952   8425333  779.445314
# 1     1957   9240934  820.853030
# 2     1962  10267083  853.100710
# 3     1967  11537966  836.197138
# 4     1972  13079460  739.981106
# ...    ...       ...         ...
# 1699  1987   9216418  706.157306
# 1700  1992  10704340  693.420786
# 1701  1997  11404948  792.449960
# 1702  2002  11926563  672.038623
# 1703  2007  12311143  469.709298
#
# [1704 rows x 3 columns]

# %%
df.iloc[:5,[2,4,-1]]
# Out:
#    year       pop   gdpPercap
# 0  1952   8425333  779.445314
# 1  1957   9240934  820.853030
# 2  1962  10267083  853.100710
# 3  1967  11537966  836.197138
# 4  1972  13079460  739.981106

# %%
df.loc[:5,["country","continent"]]
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1  Afghanistan      Asia
# 2  Afghanistan      Asia
# 3  Afghanistan      Asia
# 4  Afghanistan      Asia
# 5  Afghanistan      Asia

# %%
df.iloc[2:15,1:4]
# Out:
#    continent  year  lifeExp
# 2       Asia  1962   31.997
# 3       Asia  1967   34.020
# 4       Asia  1972   36.088
# 5       Asia  1977   38.438
# 6       Asia  1982   39.854
# 7       Asia  1987   40.822
# 8       Asia  1992   41.674
# 9       Asia  1997   41.763
# 10      Asia  2002   42.129
# 11      Asia  2007   43.828
# 12    Europe  1952   55.230
# 13    Europe  1957   59.280
# 14    Europe  1962   64.820

# %%
df.loc[2:15:2,"country":"gdpPercap"]
# Out:
#         country continent  year  lifeExp       pop    gdpPercap
# 2   Afghanistan      Asia  1962   31.997  10267083   853.100710
# 4   Afghanistan      Asia  1972   36.088  13079460   739.981106
# 6   Afghanistan      Asia  1982   39.854  12881816   978.011439
# 8   Afghanistan      Asia  1992   41.674  16317921   649.341395
# 10  Afghanistan      Asia  2002   42.129  25268405   726.734055
# 12      Albania    Europe  1952   55.230   1282697  1601.056136
# 14      Albania    Europe  1962   64.820   1728137  2312.888958

# %%
small_range=list(range(5))
df.iloc[:,small_range]
# Out:
#           country continent  year  lifeExp       pop
# 0     Afghanistan      Asia  1952   28.801   8425333
# 1     Afghanistan      Asia  1957   30.332   9240934
# 2     Afghanistan      Asia  1962   31.997  10267083
# 3     Afghanistan      Asia  1967   34.020  11537966
# 4     Afghanistan      Asia  1972   36.088  13079460
# ...           ...       ...   ...      ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418
# 1700     Zimbabwe    Africa  1992   60.377  10704340
# 1701     Zimbabwe    Africa  1997   46.809  11404948
# 1702     Zimbabwe    Africa  2002   39.989  11926563
# 1703     Zimbabwe    Africa  2007   43.487  12311143
#
# [1704 rows x 5 columns]

# %%
df.iloc[:,]
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.iloc[::,::]
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.loc[4,'country']
# Out:
# 'Afghanistan'

# %%
df.iloc[[0,4,44,444],[0,3,5]]
# Out:
#          country  lifeExp    gdpPercap
# 0    Afghanistan   28.801   779.445314
# 4    Afghanistan   36.088   739.981106
# 44        Angola   40.647  2627.845685
# 444      Ecuador   48.357  3522.110717

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df['year']==1952
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: year, Length: 1704, dtype: bool

# %%
df[df['year']==1952].shape
# Out:
# (142, 6)

# %%
df[df['year']==1952]
# Out:
#                  country continent  year  lifeExp       pop    gdpPercap
# 0            Afghanistan      Asia  1952   28.801   8425333   779.445314
# 12               Albania    Europe  1952   55.230   1282697  1601.056136
# 24               Algeria    Africa  1952   43.077   9279525  2449.008185
# 36                Angola    Africa  1952   30.015   4232095  3520.610273
# 48             Argentina  Americas  1952   62.485  17876956  5911.315053
# ...                  ...       ...   ...      ...       ...          ...
# 1644             Vietnam      Asia  1952   40.412  26246839   605.066492
# 1656  West Bank and Gaza      Asia  1952   43.160   1030585  1515.592329
# 1668         Yemen, Rep.      Asia  1952   32.548   4963829   781.717576
# 1680              Zambia    Africa  1952   42.038   2672000  1147.388831
# 1692            Zimbabwe    Africa  1952   48.451   3080907   406.884115
#
# [142 rows x 6 columns]

# %%
df.groupby("year")["lifeExp"].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df.groupby("year")["pop"].mean()
# Out:
# year
# 1952    1.695040e+07
# 1957    1.876341e+07
# 1962    2.042101e+07
# 1967    2.265830e+07
# 1972    2.518998e+07
# 1977    2.767638e+07
# 1982    3.020730e+07
# 1987    3.303857e+07
# 1992    3.599092e+07
# 1997    3.883947e+07
# 2002    4.145759e+07
# 2007    4.402122e+07
# Name: pop, dtype: float64

# %%
df.groupby(['continent','year'])['lifeExp','gdpPercap'].mean()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4756\2805814575.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['continent','year'])['lifeExp','gdpPercap'].mean()
#                   lifeExp     gdpPercap
# continent year
# Africa    1952  39.135500   1252.572466
#           1957  41.266346   1385.236062
#           1962  43.319442   1598.078825
#           1967  45.334538   2050.363801
#           1972  47.450942   2339.615674
#           1977  49.580423   2585.938508
#           1982  51.592865   2481.592960
#           1987  53.344788   2282.668991
#           1992  53.629577   2281.810333
#           1997  53.598269   2378.759555
#           2002  53.325231   2599.385159
#           2007  54.806038   3089.032605
# Americas  1952  53.279840   4079.062552
#           1957  55.960280   4616.043733
#           1962  58.398760   4901.541870
#           1967  60.410920   5668.253496
# ...

# %%
df.groupby("continent")["country"].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
global_year_lifeExp=df.groupby("year")["lifeExp"].mean()

# %%
global_year_lifeExp.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
global_year_lifeExp
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64
